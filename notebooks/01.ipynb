# %%
from pyspark.sql import SparkSession
import pyspark.pandas as ps

# %%
spark = SparkSession.builder.appName("postgres").getOrCreate()

jdbc_url = "jdbc:postgresql://postgres:5432/mydatabase"
properties = {
    "user": "user",
    "password": "password",
    "driver": "org.postgresql.Driver"
}

df = spark.read.jdbc(url=jdbc_url, table="raw_data", properties=properties)

# %%
df.toPandas()
# Out:
#       sale_id    id customer_first_name customer_last_name  customer_age  \
# 0           1     1              Barron            Rawlyns            61
# 1           2     2                 Ham           Knowller            78
# 2           3     3            Farleigh            Langley            71
# 3           4     4                Shae            Debling            28
# 4           5     5                 Lay              Twatt            25
# ...       ...   ...                 ...                ...           ...
# 9995     9996   996               Perry             Edwins            49
# 9996     9997   997            Benedick           Sherwell            71
# 9997     9998   998             Lombard            Oxtarby            42
# 9998     9999   999               Yetta            Huertas            26
# 9999    10000  1000             Bertram             Bohlje            20
#
#                 customer_email customer_country customer_postal_code  \
# 0        bmassingham0@army.mil            China                 None
# 1           cscudder1@time.com           Poland               73-115
# 2           vhuxter2@fotki.com           Poland               56-160
# 3     bbullier3@bravesites.com        Sri Lanka                81700
# 4          sedgar4@smugmug.com         Botswana                 None
# ...                        ...              ...                  ...
# 9995       mkardosrn@jimdo.com        Indonesia                 None
# 9996     ikingzettro@salon.com      El Salvador                 None
# 9997  sdrakeleyrp@bluehost.com        Indonesia                 None
# 9998     pemesrq@wikimedia.org         Pakistan                70051
# 9999         jcordenrr@home.pl           Brazil            44570-000
#
#      customer_pet_type customer_pet_name  ... product_reviews  \
# 0                  cat         Priscella  ...              97
# 1                 bird           Dalenna  ...              37
# 2                 bird          Aldridge  ...             218
# 3                  cat           Beverie  ...             959
# 4                 bird           Sydelle  ...             130
# ...                ...               ...  ...             ...
# 9995               cat            Warden  ...             355
# 9996              bird            Lezley  ...             558
# 9997              bird            Kassia  ...              55
# 9998               cat             Berri  ...             269
# 9999               dog         Kassandra  ...              75
#
#      product_release_date product_expiry_date supplier_name  supplier_contact  \
# 0              2011-10-19          2028-10-21        Tagcat  Bevan Massingham
# 1              2019-04-17          2028-02-29      Livetube   Candide Scudder
# 2              2010-02-03          2023-09-03      Photobug     Vinson Huxter
# 3              2019-08-22          2026-03-29         Janyx      Bald Bullier
# 4              2018-12-09          2030-05-10          Lazz     Sydelle Edgar
# ...                   ...                 ...           ...               ...
# 9995           2019-01-15          2024-04-09         Quire      Milty Kardos
# 9996           2014-05-25          2025-08-31        Eimbee  Isidora Kingzett
# 9997           2010-04-11          2030-03-18       Dablist   Sabine Drakeley
# 9998           2021-12-28          2029-07-29          Katz       Patric Emes
# 9999           2010-06-17          2026-04-23     Realpoint      Jenny Corden
#
#                      supplier_email supplier_phone supplier_address  \
# 0            bmassingham0@unblog.fr   914-877-7062         Suite 25
# 1              cscudder1@sbwire.com   863-319-5653       18th Floor
# 2                vhuxter2@slate.com   434-817-1275           Apt 96
# 3                 bbullier3@dot.gov   515-756-7392       12th Floor
# 4          sedgar4@reverbnation.com   861-980-8811         Suite 79
# ...                             ...            ...              ...
# 9995   mkardosrn@barnesandnoble.com   688-242-0789         Suite 47
# 9996         ikingzettro@eepurl.com   279-253-6631           Apt 79
# 9997  sdrakeleyrp@timesonline.co.uk   469-421-9241     PO Box 84909
# 9998        pemesrq@bizjournals.com   855-954-7325        Room 1617
# 9999        jcordenrr@moonfruit.com   686-812-9389         Suite 95
#
#            supplier_city  supplier_country
# 0                 Kletek             China
# 1     Santa Cruz Balanyá            Poland
# 2                Huangpu             Samoa
# 3             Chengzhong         Indonesia
# 4                  Lanxi             China
# ...                  ...               ...
# 9995  São Caetano do Sul            Brazil
# 9996              Aoqiao           Ukraine
# 9997              Dallas            France
# 9998             Lingion           Jamaica
# 9999              Plesná    Czech Republic
#
# [10000 rows x 51 columns]
